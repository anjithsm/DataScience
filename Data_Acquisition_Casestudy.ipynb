# %% [markdown]
# <a href="https://colab.research.google.com/github/anjithsm/DataScience/blob/main/Data_Acquisition_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Load the dataset into a pandas DataFrame.
import pandas as pd

# %%
df = pd.read_csv("/content/fifa_players.csv")

# %%
#Display the first few rows of the DataFrame to understand its structure
df.head()
# Out:
#            name                       full_name birth_date  age  height_cm  \
# 0      L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# 1    C. Eriksen    Christian  Dannemann Eriksen  2/14/1992   27     154.94
# 2      P. Pogba                      Paul Pogba  3/15/1993   25     190.50
# 3    L. Insigne                 Lorenzo Insigne   6/4/1991   27     162.56
# 4  K. Koulibaly               Kalidou Koulibaly  6/20/1991   27     187.96
#
#    weight_kgs  positions nationality  overall_rating  potential  ...  \
# 0        72.1   CF,RW,ST   Argentina              94         94  ...
# 1        76.2  CAM,RM,CM     Denmark              88         89  ...
# 2        83.9     CM,CAM      France              88         91  ...
# 3        59.0      LW,ST       Italy              88         88  ...
# 4        88.9         CB     Senegal              88         91  ...
#
#    long_shots  aggression interceptions  positioning  vision  penalties  \
# ...

# %%
#Print the summary statistics of the dataset
summary = df.describe()
summary
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17708.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.687014e+06   21995.593750                       0.392168
# ...

# %% [markdown]
# ### **Q1. What is the size of the dataset? (Number of rows and columns)**

# %%
df.shape
# Out:
# (17954, 51)

# %% [markdown]
# ### **Q2.What are the data types of each column?**

# %%
df.dtypes
# Out:
# name                              object
# full_name                         object
# birth_date                        object
# age                                int64
# height_cm                        float64
# weight_kgs                       float64
# positions                         object
# nationality                       object
# overall_rating                     int64
# potential                          int64
# value_euro                       float64
# wage_euro                        float64
# preferred_foot                    object
# international_reputation(1-5)      int64
# weak_foot(1-5)                     int64
# skill_moves(1-5)                   int64
# body_type                         object
# release_clause_euro              float64
# national_team                     object
# national_rating                  float64
# national_team_position            object
# national_jersey_number           float64
# crossing                           int64
# ...

# %% [markdown]
# ### **Q3.Are there any missing values in the dataset? If so, which columns have missing values and how many?**

# %%
df.isnull()
# Out:
#         name  full_name  birth_date    age  height_cm  weight_kgs  positions  \
# 0      False      False       False  False      False       False      False
# 1      False      False       False  False      False       False      False
# 2      False      False       False  False      False       False      False
# 3      False      False       False  False      False       False      False
# 4      False      False       False  False      False       False      False
# ...      ...        ...         ...    ...        ...         ...        ...
# 17949  False      False       False  False      False       False      False
# 17950  False      False       False  False      False       False      False
# 17951  False      False       False  False      False       False      False
# 17952  False      False       False  False      False       False      False
# 17953  False      False       False  False      False       False      False
#
# ...

# %%
missin_values_count = df.isnull().sum()
missin_values_count
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# national_rating                  17097
# national_team_position           17097
# national_jersey_number           17097
# crossing                             0
# finishing                            0
# ...

# %% [markdown]
# ### **Q4.What are the unique values in a categorical column of your choice? How many unique values are there?**

# %%
unique_value = df['full_name'].unique()
print(unique_value)
df['full_name'].nunique()
# Out:
# ['Lionel Andrés Messi Cuccittini' 'Christian  Dannemann Eriksen'
#  'Paul Pogba' ... 'Jan Bekkema' 'Abdulrahman Al Yami'
#  'José Francisco dos Santos Júnior']
# 17898

# %% [markdown]
# ### **Q5.For a numerical column of your choice, calculate the mean, median, and standard deviation.**

# %%
mean_median_std = df['overall_rating'].agg(['mean','median','std'])

print(mean_median_std)
# Out:
# mean      66.240169
# median    66.000000
# std        6.963730
# Name: overall_rating, dtype: float64

# %% [markdown]
# ### **Q6.: Identify any potential outliers in a numerical column of your choice. Explain your approach.**

# %%
column = 'ball_control'
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
outliers
# Out:
#                     name                            full_name  birth_date  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   6/24/1987
# 3             L. Insigne                      Lorenzo Insigne    6/4/1991
# 11           T. Courtois                     Thibaut Courtois   5/11/1992
# 12         M. ter Stegen                Marc-André ter Stegen   4/30/1992
# 15             P. Dybala          Paulo Bruno Exequiel Dybala  11/15/1993
# ...                  ...                                  ...         ...
# 17939          L. Modrić                          Luka Modrić    9/9/1985
# 17940          E. Hazard                          Eden Hazard    1/7/1991
# 17943          Neymar Jr        Neymar da Silva Santos Junior    2/5/1992
# 17944  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro    2/5/1985
# 17951         J. Bekkema                          Jan Bekkema    4/9/1996
#
#        age  height_cm  weight_kgs positions  nationality  overall_rating  \
# ...

# %% [markdown]
# ### **Q7.Find the correlation between numerical columns and discuss any interesting relationships**

# %%
correlation = df['crossing'].corr(df['finishing'])
correlation
# Out:
# 0.6641825951455514

# %% [markdown]
# ### **Q8: Group the data by a categorical column and compute the aggregate statistics (e.g., mean, sum) for a numerical column.**

# %%
grouped_df = df.groupby('ball_control')['ball_control'].agg(['mean', 'sum'])
grouped_df
# Out:
#               mean  sum
# ball_control
# 5              5.0    5
# 8              8.0   16
# 9              9.0   45
# 10            10.0  510
# 11            11.0  682
# ...            ...  ...
# 92            92.0  368
# 93            93.0   93
# 94            94.0  282
# 95            95.0  190
# 96            96.0   96
#
# [90 rows x 2 columns]

# %% [markdown]
# ### **Q9: Based on your analysis, provide a brief summary of any insights or patterns you discovered in the dataset**
#
#   The dataset is fairly large, with 17,954 records and 51 columns, offering a comprehensive view of player attributes, performance metrics, and physical characteristics
